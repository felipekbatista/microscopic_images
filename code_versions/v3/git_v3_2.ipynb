# %% [markdown]
# <a href="https://colab.research.google.com/github/felipekbatista/microscopic_images/blob/master/code_versions/v3/git_v3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# My first git upload

# %% [markdown]
# texto escrito aqui
# # ìndice lvl 1

# %% [markdown]
# Alterações #2 realizadas: novas linhas de texto e código adicionadas

# %%
# linha de código #2 adicionada

# %% [markdown]
# # índice lvl 1 - v3
# alterações #3 realizadas:
# adição de cálculos e printos

# %%
a = 1
b = 2
c = 3
print('a + b = ', a + b)
print('a*b = ', a*b)
# Out:
# a + b =  3
# a*b =  2

# %% [markdown]
# Save this into code_versionf folder

# %% [markdown]
# ---
# v3.2 will have an output img to be saved together

# %%
from skimage import io

# %%
img = io.imread('modelo_01.jpg')
io.imshow(img)

# %%
io.imsave('test_img_v1.jpg',img  )
